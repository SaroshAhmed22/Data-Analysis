# %%
#Make a class called Employee. The __init__() method for Employee should store its different attributes: name, number, address, salary, 
#post, year of joining, education, and his year of experience.
class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, years_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.years_of_experience = years_of_experience

    def employee_info(self):
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: {self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.years_of_experience}")


# Example of creating an Employee object and displaying its information
our_employee1 = Employee(
    name="Sarosh",
    number="2121112",
    address="Karachi",
    salary=10000,
    post="Data Engineer",
    year_of_joining=2022,
    education="COmputer ENgineering",
    years_of_experience=5
)

our_employee1.employee_info()
# Out:
# Name: Sarosh
# Number: 2121112
# Address: Karachi
# Salary: 10000
# Post: Data Engineer
# Year of Joining: 2022
# Education: COmputer ENgineering
# Years of Experience: 5

# %% [markdown]
# ### Without OOP

# %%
# Define the employee as a dictionary
employee101 = {
    'name': "John Doe",
    'number': "101",
    'address': "123 Elm St",
    'salary': 50000,
    'post': "Developer",
    'year_of_joining': 2018,
    'education': "B.Sc. in Computer Science",
    'year_of_experience': 5
}

# Function to describe employee
def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: {employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['year_of_experience']}")

# Function to update years of experience
def update_year_of_experience(employee, additional_years):
    employee['year_of_experience'] += additional_years

# Function to increase salary
def increase_salary(employee, increment):
    employee['salary'] += increment

# Print the four attributes individually
print(employee101['name'])
print(employee101['number'])
print(employee101['address'])
print(employee101['salary'])

# Calling the functions
describe_employee(employee101)
increase_salary(employee101, 5000)
update_year_of_experience(employee101, 1)

# Calling the describe function again to show updates
describe_employee(employee101)
# Out:
# John Doe
# 101
# 123 Elm St
# 50000
# Name: John Doe
# Number: 101
# Address: 123 Elm St
# Salary: 50000
# Post: Developer
# Year of Joining: 2018
# Education: B.Sc. in Computer Science
# Years of Experience: 5
# Name: John Doe
# Number: 101
# Address: 123 Elm St
# Salary: 55000
# Post: Developer
# Year of Joining: 2018
# Education: B.Sc. in Computer Science
# Years of Experience: 6

# %%
#Make a method called describe_employee() that prints the detail Information about employee, a method update_ year_of_experience(),
#and a method called increase_salary() that do increamnet in it's salary.


class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, years_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.years_of_experience = years_of_experience

    def describe_employee(self):
        """Prints detailed information about the employee."""
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: ${self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.years_of_experience}")

    def update_year_of_experience(self, new_experience):
        """Updates the years of experience for the employee."""
        if new_experience >= self.years_of_experience:
            self.years_of_experience = new_experience
            print(f"Years of experience updated to: {self.years_of_experience} years.")
        else:
            print("New experience must be greater than or equal to the current experience.")

    def increase_salary(self, increment):
       
        if increment > 0:
            self.salary += increment
            print(f"Salary increased by ${increment}. New salary is: ${self.salary}.")
        else:
            print("Increment must be a positive value.")


# Example of using the Employee class
employee1 = Employee(
   name="Sarosh",
    number="2121112",
    address="Karachi",
    salary=10000,
    post="Data Engineer",
    year_of_joining=2022,
    education="COmputer ENgineering",
    years_of_experience=5
)

# Display employee information
employee1.describe_employee()

# Update years of experience
employee1.update_year_of_experience(6)

# Increase salary
employee1.increase_salary(5000)
# Out:
# Name: Sarosh
# Number: 2121112
# Address: Karachi
# Salary: $10000
# Post: Data Engineer
# Year of Joining: 2022
# Education: COmputer ENgineering
# Years of Experience: 5
# Years of experience updated to: 6 years.
# Salary increased by $5000. New salary is: $15000.

# %% [markdown]
# ## WIthout OOP

# %%
# Define the employee data as a dictionary
employee101 = {
    'name': "John Doe",
    'number': "101",
    'address': "123 Elm St",
    'salary': 50000,
    'post': "Developer",
    'year_of_joining': 2018,
    'education': "B.Sc. in Computer Science",
    'year_of_experience': 5
}

# Function to describe the employee
def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: ${employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['year_of_experience']}")

# Function to update years of experience
def update_year_of_experience(employee, additional_years):
    employee['year_of_experience'] += additional_years
    print(f"Years of experience updated to: {employee['year_of_experience']}")

# Function to increase salary
def increase_salary(employee, increment):
    employee['salary'] += increment
    print(f"Salary increased to: ${employee['salary']}")

# Call the functions with the employee data
describe_employee(employee101)
increase_salary(employee101, 5000)
update_year_of_experience(employee101, 1)
# Out:
# Name: John Doe
# Number: 101
# Address: 123 Elm St
# Salary: $50000
# Post: Developer
# Year of Joining: 2018
# Education: B.Sc. in Computer Science
# Years of Experience: 5
# Salary increased to: $55000
# Years of experience updated to: 6

# %%
#Make an instance called employee101 from your class. Print the four attri-butes individually,
#and then call all it's methods for describing employee, ssalary increamnet and increase year of experience.


class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, years_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.years_of_experience = years_of_experience

    def describe_employee(self):
        """Prints detailed information about the employee."""
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: ${self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.years_of_experience}")

    def update_year_of_experience(self, new_experience):
        """Updates the years of experience for the employee."""
        if new_experience >= self.years_of_experience:
            self.years_of_experience = new_experience
            print(f"Years of experience updated to: {self.years_of_experience} years.")
        else:
            print("New experience must be greater than or equal to the current experience.")

    def increase_salary(self, increment):
        """Increases the salary of the employee by a given increment."""
        if increment > 0:
            self.salary += increment
            print(f"Salary increased by ${increment}. New salary is: ${self.salary}.")
        else:
            print("Increment must be a positive value.")


# Creating an instance called employee101
employee101 = Employee(
     name="Sarosh",
    number="2121112",
    address="Karachi",
    salary=10000,
    post="Data Engineer",
    year_of_joining=2022,
    education="Computer ENgineering",
    years_of_experience=5
)

# Printing the four attributes individually
print(f"Name: {employee101.name}")
print(f"Number: {employee101.number}")

print(f"Address: {employee101.address}")
print(f"Salary: ${employee101.salary}")

# Calling methods on the instance
employee101.describe_employee()          
employee101.increase_salary(7000)        
employee101.update_year_of_experience(10)
# Out:
# Name: Alice Johnson
# Number: E101
# Address: 456 Elm St, Townsville
# Salary: $60000
# Name: Alice Johnson
# Number: E101
# Address: 456 Elm St, Townsville
# Salary: $60000
# Post: Project Manager
# Year of Joining: 2015
# Education: MBA
# Years of Experience: 8
# Salary increased by $7000. New salary is: $67000.
# Years of experience updated to: 10 years.

# %% [markdown]
# ## Without OOP

# %%
# Define the employee data as a dictionary
employee101 = {
    'name': "John Doe",
    'number': "101",
    'address': "123 Elm St",
    'salary': 50000,
    'post': "Developer",
    'year_of_joining': 2018,
    'education': "B.Sc. in Computer Science",
    'year_of_experience': 5
}

# Function to describe the employee
def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: ${employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['year_of_experience']}")

# Function to update years of experience
def update_year_of_experience(employee, additional_years):
    employee['year_of_experience'] += additional_years
    print(f"Years of experience updated to: {employee['year_of_experience']}")

# Function to increase salary
def increase_salary(employee, increment):
    employee['salary'] += increment
    print(f"Salary increased to: ${employee['salary']}")

# Print the four attributes individually
print(employee101['name'])
print(employee101['number'])
print(employee101['address'])
print(employee101['salary'])

# Call the functions with the employee data
describe_employee(employee101)
increase_salary(employee101, 5000)
update_year_of_experience(employee101, 1)
# Out:
# John Doe
# 101
# 123 Elm St
# 50000
# Name: John Doe
# Number: 101
# Address: 123 Elm St
# Salary: $50000
# Post: Developer
# Year of Joining: 2018
# Education: B.Sc. in Computer Science
# Years of Experience: 5
# Salary increased to: $55000
# Years of experience updated to: 6

# %%
#Create 10 different instances from the class, and call describe_employee() for each
#instance. Then do some updations with it's methods.



class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, years_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.years_of_experience = years_of_experience

    def describe_employee(self):
        """Prints detailed information about the employee."""
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: ${self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.years_of_experience}\n")

    def update_year_of_experience(self, new_experience):
        """Updates the years of experience for the employee."""
        if new_experience >= self.years_of_experience:
            self.years_of_experience = new_experience
            print(f"Years of experience updated to: {self.years_of_experience} years.\n")
        else:
            print("New experience must be greater than or equal to the current experience.\n")

    def increase_salary(self, increment):
        """Increases the salary of the employee by a given increment."""
        if increment > 0:
            self.salary += increment
            print(f"Salary increased by ${increment}. New salary is: ${self.salary}.\n")
        else:
            print("Increment must be a positive value.\n")


# Creating 10 different instances of the Employee class
employees = [
    Employee("Sarosh", "1", "456 Elm St, Townsville", 3213123123, "Project Manager", 2015, "MBA", 8),
    Employee("ALi", "2", "789 Maple Ave, Cityville", 55312312312000, "Software Engineer", 2017, "BSc Computer Science", 6),
    Employee("Kamran", "3", "101 Oak St, Villagetown", 2312312312, "QA Engineer", 2018, "BTech IT", 5),
    Employee("Umar", "4", "202 Pine Rd, Metrocity", 3123123, "Data Scientist", 2014, "MSc Data Science", 9),
    Employee("Shakir", "5", "303 Cedar Ln, Urbanville", 65012312312300, "Product Manager", 2016, "MBA", 7),
    Employee("Sarfaraz", "6", "404 Birch Blvd, Suburbia", 31231231231, "DevOps Engineer", 2019, "BSc Information Systems", 4),
    Employee("Abdullah", "7", "505 Spruce Ct, Downtown", 52354255654000, "UX Designer", 2018, "BFA Design", 5),
    Employee("Noman", "8", "606 Fir Dr, Uptown", 590005554, "Marketing Specialist", 2016, "BBA Marketing", 7),
    Employee("Kiran", "9", "707 Redwood Pl, Riverside", 89766565, "Business Analyst", 2015, "BSc Economics", 8),
    Employee("Babar", "10", "808 Sequoia St, Lakeside", 32323232323, "Finance Manager", 2013, "MSc Finance", 10),
]

# Calling describe_employee() for each instance and performing updates
for employee in employees:
    employee.describe_employee()

# Perform updates with methods for some employees
print("Updating employee details:\n")
employees[0].increase_salary(5000)               # Alice Johnson
employees[1].update_year_of_experience(7)        # Bob Smith
employees[2].increase_salary(3000)               # Charlie Brown
employees[3].update_year_of_experience(10)       # David Wilson
employees[4].increase_salary(2000)               # Eva Green
# Out:
# Name: Sarosh
# Number: 1
# Address: 456 Elm St, Townsville
# Salary: $3213123123
# Post: Project Manager
# Year of Joining: 2015
# Education: MBA
# Years of Experience: 8
#
# Name: ALi
# Number: 2
# Address: 789 Maple Ave, Cityville
# Salary: $55312312312000
# Post: Software Engineer
# Year of Joining: 2017
# Education: BSc Computer Science
# Years of Experience: 6
#
# Name: Kamran
# Number: 3
# Address: 101 Oak St, Villagetown
# Salary: $2312312312
# Post: QA Engineer
# Year of Joining: 2018
# Education: BTech IT
# Years of Experience: 5
#
# Name: Umar
# Number: 4
# Address: 202 Pine Rd, Metrocity
# Salary: $3123123
# Post: Data Scientist
# Year of Joining: 2014
# Education: MSc Data Science
# Years of Experience: 9
#
# Name: Shakir
# Number: 5
# Address: 303 Cedar Ln, Urbanville
# Salary: $65012312312300
# Post: Product Manager
# Year of Joining: 2016
# Education: MBA
# Years of Experience: 7
#
# Name: Sarfaraz
# Number: 6
# Address: 404 Birch Blvd, Suburbia
# Salary: $31231231231
# ...

# %%
# Function to describe an employee
def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: ${employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['years_of_experience']}\n")

# Function to update the years of experience for an employee
def update_year_of_experience(employee, new_experience):
    if new_experience >= employee['years_of_experience']:
        employee['years_of_experience'] = new_experience
        print(f"Years of experience updated to: {employee['years_of_experience']} years.\n")
    else:
        print("New experience must be greater than or equal to the current experience.\n")

# Function to increase the salary of an employee
def increase_salary(employee, increment):
    if increment > 0:
        employee['salary'] += increment
        print(f"Salary increased by ${increment}. New salary is: ${employee['salary']}.\n")
    else:
        print("Increment must be a positive value.\n")

# Creating 10 employee records using dictionaries
employees = [
    {'name': "Alice Johnson", 'number': "E101", 'address': "456 Elm St, Townsville", 'salary': 60000, 
     'post': "Project Manager", 'year_of_joining': 2015, 'education': "MBA", 'years_of_experience': 8},
    
    {'name': "Bob Smith", 'number': "E102", 'address': "789 Maple Ave, Cityville", 'salary': 55000, 
     'post': "Software Engineer", 'year_of_joining': 2017, 'education': "BSc Computer Science", 'years_of_experience': 6},
    
    {'name': "Charlie Brown", 'number': "E103", 'address': "101 Oak St, Villagetown", 'salary': 48000, 
     'post': "QA Engineer", 'year_of_joining': 2018, 'education': "BTech IT", 'years_of_experience': 5},
    
    {'name': "David Wilson", 'number': "E104", 'address': "202 Pine Rd, Metrocity", 'salary': 72000, 
     'post': "Data Scientist", 'year_of_joining': 2014, 'education': "MSc Data Science", 'years_of_experience': 9},
    
    {'name': "Eva Green", 'number': "E105", 'address': "303 Cedar Ln, Urbanville", 'salary': 65000, 
     'post': "Product Manager", 'year_of_joining': 2016, 'education': "MBA", 'years_of_experience': 7},
    
    {'name': "Frank Harris", 'number': "E106", 'address': "404 Birch Blvd, Suburbia", 'salary': 47000, 
     'post': "DevOps Engineer", 'year_of_joining': 2019, 'education': "BSc Information Systems", 'years_of_experience': 4},
    
    {'name': "Grace Lee", 'number': "E107", 'address': "505 Spruce Ct, Downtown", 'salary': 52000, 
     'post': "UX Designer", 'year_of_joining': 2018, 'education': "BFA Design", 'years_of_experience': 5},
    
    {'name': "Hank Miller", 'number': "E108", 'address': "606 Fir Dr, Uptown", 'salary': 59000, 
     'post': "Marketing Specialist", 'year_of_joining': 2016, 'education': "BBA Marketing", 'years_of_experience': 7},
    
    {'name': "Ivy Davis", 'number': "E109", 'address': "707 Redwood Pl, Riverside", 'salary': 68000, 
     'post': "Business Analyst", 'year_of_joining': 2015, 'education': "BSc Economics", 'years_of_experience': 8},
    
    {'name': "Jack White", 'number': "E110", 'address': "808 Sequoia St, Lakeside", 'salary': 75000, 
     'post': "Finance Manager", 'year_of_joining': 2013, 'education': "MSc Finance", 'years_of_experience': 10}
]

# Describing each employee and performing updates
for employee in employees:
    describe_employee(employee)

print("Updating employee details:\n")

# Updating the details of some employees
increase_salary(employees[0], 5000)          # Increase salary for Alice Johnson
update_year_of_experience(employees[1], 7)   # Update experience for Bob Smith
increase_salary(employees[2], 3000)          # Increase salary for Charlie Brown
update_year_of_experience(employees[3], 10)  # Update experience for David Wilson
increase_salary(employees[4], 2000)          # Increase salary for Eva Green
# Out:
# Name: Alice Johnson
# Number: E101
# Address: 456 Elm St, Townsville
# Salary: $60000
# Post: Project Manager
# Year of Joining: 2015
# Education: MBA
# Years of Experience: 8
#
# Name: Bob Smith
# Number: E102
# Address: 789 Maple Ave, Cityville
# Salary: $55000
# Post: Software Engineer
# Year of Joining: 2017
# Education: BSc Computer Science
# Years of Experience: 6
#
# Name: Charlie Brown
# Number: E103
# Address: 101 Oak St, Villagetown
# Salary: $48000
# Post: QA Engineer
# Year of Joining: 2018
# Education: BTech IT
# Years of Experience: 5
#
# Name: David Wilson
# Number: E104
# Address: 202 Pine Rd, Metrocity
# Salary: $72000
# Post: Data Scientist
# Year of Joining: 2014
# Education: MSc Data Science
# Years of Experience: 9
#
# Name: Eva Green
# Number: E105
# Address: 303 Cedar Ln, Urbanville
# Salary: $65000
# Post: Product Manager
# Year of Joining: 2016
# Education: MBA
# Years of Experience: 7
#
# Name: Frank Harris
# Number: E106
# Address: 404 Birch Blvd, Suburbia
# ...

# %% [markdown]
# ## ## WIthout OOP

# %%
# Function to describe an employee
def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: ${employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['years_of_experience']}\n")

# Function to update the years of experience for an employee
def update_year_of_experience(employee, new_experience):
    if new_experience >= employee['years_of_experience']:
        employee['years_of_experience'] = new_experience
        print(f"Years of experience updated to: {employee['years_of_experience']} years.\n")
    else:
        print("New experience must be greater than or equal to the current experience.\n")

# Function to increase the salary of an employee
def increase_salary(employee, increment):
    if increment > 0:
        employee['salary'] += increment
        print(f"Salary increased by ${increment}. New salary is: ${employee['salary']}.\n")
    else:
        print("Increment must be a positive value.\n")

# Creating 10 employee records using dictionaries
employees = [
    {'name': "Sarosh", 'number': "E101", 'address': "456 Elm St, Townsville", 'salary': 60000, 
     'post': "Project Manager", 'year_of_joining': 2015, 'education': "MBA", 'years_of_experience': 8},
    
    {'name': "ALi", 'number': "E102", 'address': "789 Maple Ave, Cityville", 'salary': 55000, 
     'post': "Software Engineer", 'year_of_joining': 2017, 'education': "BSc Computer Science", 'years_of_experience': 6},
    
    {'name': "Kamran", 'number': "E103", 'address': "101 Oak St, Villagetown", 'salary': 48000, 
     'post': "QA Engineer", 'year_of_joining': 2018, 'education': "BTech IT", 'years_of_experience': 5},
    
    {'name': "Shahzaib", 'number': "E104", 'address': "202 Pine Rd, Metrocity", 'salary': 72000, 
     'post': "Data Scientist", 'year_of_joining': 2014, 'education': "MSc Data Science", 'years_of_experience': 9},
    
    {'name': "Farjad", 'number': "E105", 'address': "303 Cedar Ln, Urbanville", 'salary': 65000, 
     'post': "Product Manager", 'year_of_joining': 2016, 'education': "MBA", 'years_of_experience': 7},
    
    {'name': "Ali", 'number': "E106", 'address': "404 Birch Blvd, Suburbia", 'salary': 47000, 
     'post': "DevOps Engineer", 'year_of_joining': 2019, 'education': "BSc Information Systems", 'years_of_experience': 4},
    
    {'name': "ABdullah", 'number': "E107", 'address': "505 Spruce Ct, Downtown", 'salary': 52000, 
     'post': "UX Designer", 'year_of_joining': 2018, 'education': "BFA Design", 'years_of_experience': 5},
    
    {'name': "Hanif", 'number': "E108", 'address': "606 Fir Dr, Uptown", 'salary': 59000, 
     'post': "Marketing Specialist", 'year_of_joining': 2016, 'education': "BBA Marketing", 'years_of_experience': 7},
    
    {'name': "Kami", 'number': "E109", 'address': "707 Redwood Pl, Riverside", 'salary': 68000, 
     'post': "Business Analyst", 'year_of_joining': 2015, 'education': "BSc Economics", 'years_of_experience': 8},
    
    {'name': "Furqan", 'number': "E110", 'address': "808 Sequoia St, Lakeside", 'salary': 75000, 
     'post': "Finance Manager", 'year_of_joining': 2013, 'education': "MSc Finance", 'years_of_experience': 10}
]

# Describing each employee and performing updates
for employee in employees:
    describe_employee(employee)

print("Updating employee details:\n")

# Updating the details of some employees
increase_salary(employees[0], 5000)          
update_year_of_experience(employees[1], 7) 
increase_salary(employees[2], 3000)          
update_year_of_experience(employees[3], 10) 
increase_salary(employees[4], 2000)
# Out:
# Name: Sarosh
# Number: E101
# Address: 456 Elm St, Townsville
# Salary: $60000
# Post: Project Manager
# Year of Joining: 2015
# Education: MBA
# Years of Experience: 8
#
# Name: ALi
# Number: E102
# Address: 789 Maple Ave, Cityville
# Salary: $55000
# Post: Software Engineer
# Year of Joining: 2017
# Education: BSc Computer Science
# Years of Experience: 6
#
# Name: Kamran
# Number: E103
# Address: 101 Oak St, Villagetown
# Salary: $48000
# Post: QA Engineer
# Year of Joining: 2018
# Education: BTech IT
# Years of Experience: 5
#
# Name: Shahzaib
# Number: E104
# Address: 202 Pine Rd, Metrocity
# Salary: $72000
# Post: Data Scientist
# Year of Joining: 2014
# Education: MSc Data Science
# Years of Experience: 9
#
# Name: Farjad
# Number: E105
# Address: 303 Cedar Ln, Urbanville
# Salary: $65000
# Post: Product Manager
# Year of Joining: 2016
# Education: MBA
# Years of Experience: 7
#
# Name: Ali
# Number: E106
# Address: 404 Birch Blvd, Suburbia
# Salary: $47000
# ...
