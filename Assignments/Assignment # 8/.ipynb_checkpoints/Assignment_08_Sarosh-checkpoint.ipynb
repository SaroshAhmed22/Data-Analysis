# %%
import csv
open_file = open('data.csv',mode='r')
full_data = csv.reader(open_file)

all_data = list(full_data)

Header=all_data[0]
Header
# Out:
# ['roll no', 'Name', 'Chemistry', 'Physics', 'Math']

# %%
student_data = all_data[1:]
student_data
# Out:
# [['101', 'Aliza', '50', '23', '87'],
#  ['102', 'Fareed', '45', '24', '88'],
#  ['103', 'Basit', '46', '25', '89'],
#  ['104', 'Abdullah', '47', '26', '90'],
#  ['105', 'Ali', '48', '27', '67'],
#  ['106', 'Mubashir', '49', '28', '68'],
#  ['107', 'Waleed', '50', '29', '69'],
#  ['108', 'Mansoor', '51', '30', '70'],
#  ['109', 'Zain', '52', '31', '71'],
#  ['110', 'Mohsin', '53', '67', '72'],
#  ['111', 'Shahmeer', '54', '68', '73'],
#  ['112', 'Rao', '55', '69', '74'],
#  ['113', 'Aurangzeb', '56', '70', '75'],
#  ['114', 'Zeeshan', '57', '71', '76'],
#  ['115', 'Hamna', '58', '72', '77'],
#  ['116', 'Hamza', '59', '73', '78'],
#  ['117', 'Khalid', '60', '74', '79'],
#  ['118', 'Behroz', '61', '75', '80'],
#  ['119', 'Justin', '62', '76', '81'],
#  ['120', 'Danish', '63', '77', '82'],
#  ['121', 'Kainat', '64', '78', '83'],
#  ['122', 'Sameer', '65', '79', '84'],
#  ['123', 'Raza', '66', '80', '85'],
#  ['124', 'Kumar', '67', '81', '86'],
#  ['125', 'Komal', '68', '82', '87'],
# ...

# %%
student_data[0]
# Out:
# ['101', 'Aliza', '50', '23', '87']

# %%
for separated_marks in student_data:
    Chemistry_marks=int(separated_marks[2])
    Physics_marks=int(separated_marks[3])
    Math_marks=int(separated_marks[4])
    student_percentage= round(((Chemistry_marks+Math_marks+Physics_marks)*100)/300,2)
    print(student_percentage)
    separated_marks.append(student_percentage)
    print(separated_marks)
# Out:
# 53.33
# ['101', 'Aliza', '50', '23', '87', 53.33]
# 52.33
# ['102', 'Fareed', '45', '24', '88', 52.33]
# 53.33
# ['103', 'Basit', '46', '25', '89', 53.33]
# 54.33
# ['104', 'Abdullah', '47', '26', '90', 54.33]
# 47.33
# ['105', 'Ali', '48', '27', '67', 47.33]
# 48.33
# ['106', 'Mubashir', '49', '28', '68', 48.33]
# 49.33
# ['107', 'Waleed', '50', '29', '69', 49.33]
# 50.33
# ['108', 'Mansoor', '51', '30', '70', 50.33]
# 51.33
# ['109', 'Zain', '52', '31', '71', 51.33]
# 64.0
# ['110', 'Mohsin', '53', '67', '72', 64.0]
# 65.0
# ['111', 'Shahmeer', '54', '68', '73', 65.0]
# 66.0
# ['112', 'Rao', '55', '69', '74', 66.0]
# 67.0
# ['113', 'Aurangzeb', '56', '70', '75', 67.0]
# 68.0
# ['114', 'Zeeshan', '57', '71', '76', 68.0]
# 69.0
# ['115', 'Hamna', '58', '72', '77', 69.0]
# 70.0
# ['116', 'Hamza', '59', '73', '78', 70.0]
# 71.0
# ['117', 'Khalid', '60', '74', '79', 71.0]
# 72.0
# ['118', 'Behroz', '61', '75', '80', 72.0]
# 73.0
# ['119', 'Justin', '62', '76', '81', 73.0]
# 74.0
# ...

# %%
student_data
# Out:
# [['101', 'Aliza', '50', '23', '87', 53.33],
#  ['102', 'Fareed', '45', '24', '88', 52.33],
#  ['103', 'Basit', '46', '25', '89', 53.33],
#  ['104', 'Abdullah', '47', '26', '90', 54.33],
#  ['105', 'Ali', '48', '27', '67', 47.33],
#  ['106', 'Mubashir', '49', '28', '68', 48.33],
#  ['107', 'Waleed', '50', '29', '69', 49.33],
#  ['108', 'Mansoor', '51', '30', '70', 50.33],
#  ['109', 'Zain', '52', '31', '71', 51.33],
#  ['110', 'Mohsin', '53', '67', '72', 64.0],
#  ['111', 'Shahmeer', '54', '68', '73', 65.0],
#  ['112', 'Rao', '55', '69', '74', 66.0],
#  ['113', 'Aurangzeb', '56', '70', '75', 67.0],
#  ['114', 'Zeeshan', '57', '71', '76', 68.0],
#  ['115', 'Hamna', '58', '72', '77', 69.0],
#  ['116', 'Hamza', '59', '73', '78', 70.0],
#  ['117', 'Khalid', '60', '74', '79', 71.0],
#  ['118', 'Behroz', '61', '75', '80', 72.0],
#  ['119', 'Justin', '62', '76', '81', 73.0],
#  ['120', 'Danish', '63', '77', '82', 74.0],
#  ['121', 'Kainat', '64', '78', '83', 75.0],
# ...

# %%
Header.append('Percentage')

# %%
all_data[0]
# Out:
# ['roll no', 'Name', 'Chemistry', 'Physics', 'Math', 'Percentage']

# %%
all_data
# Out:
# [['roll no', 'Name', 'Chemistry', 'Physics', 'Math', 'Percentage'],
#  ['101', 'Aliza', '50', '23', '87', 53.33],
#  ['102', 'Fareed', '45', '24', '88', 52.33],
#  ['103', 'Basit', '46', '25', '89', 53.33],
#  ['104', 'Abdullah', '47', '26', '90', 54.33],
#  ['105', 'Ali', '48', '27', '67', 47.33],
#  ['106', 'Mubashir', '49', '28', '68', 48.33],
#  ['107', 'Waleed', '50', '29', '69', 49.33],
#  ['108', 'Mansoor', '51', '30', '70', 50.33],
#  ['109', 'Zain', '52', '31', '71', 51.33],
#  ['110', 'Mohsin', '53', '67', '72', 64.0],
#  ['111', 'Shahmeer', '54', '68', '73', 65.0],
#  ['112', 'Rao', '55', '69', '74', 66.0],
#  ['113', 'Aurangzeb', '56', '70', '75', 67.0],
#  ['114', 'Zeeshan', '57', '71', '76', 68.0],
#  ['115', 'Hamna', '58', '72', '77', 69.0],
#  ['116', 'Hamza', '59', '73', '78', 70.0],
#  ['117', 'Khalid', '60', '74', '79', 71.0],
#  ['118', 'Behroz', '61', '75', '80', 72.0],
#  ['119', 'Justin', '62', '76', '81', 73.0],
#  ['120', 'Danish', '63', '77', '82', 74.0],
# ...

# %%
open_file = open("data2.csv",mode='w',newline='')
open_file

writer = csv.writer(open_file)
writer
writer.writerows(all_data)
open_file.close()
