# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('PS4_GamesSales.csv', encoding='ISO-8859-1', index_col=0 )
df
# Out:
#                                     Game    Year             Genre  \
# S_no
# 1                     Grand Theft Auto V  2014.0            Action
# 2              Call of Duty: Black Ops 3  2015.0           Shooter
# 3                  Red Dead Redemption 2  2018.0  Action-Adventure
# 4                     Call of Duty: WWII  2017.0           Shooter
# 5                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1030  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1031            Radial G Racing Revolved  2017.0            Racing
# 1032                The Mummy Demastered     NaN            Action
# 1033          Project Nimbus: Code Mirai     NaN            Action
# 1034                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# S_no
# 1     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
df.shape
# Out:
# (1034, 9)

# %%
 pd.options.display.max_rows = None

# %%
df.info()  ##209 Year and Publisher missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1034 entries, 1 to 1034
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           1034 non-null   object
#  1   Year           825 non-null    float64
#  2   Genre          1034 non-null   object
#  3   Publisher      825 non-null    object
#  4   North America  1034 non-null   float64
#  5   Europe         1034 non-null   float64
#  6   Japan          1034 non-null   float64
#  7   Rest of World  1034 non-null   float64
#  8   Global         1034 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 80.8+ KB

# %%
df['Game'].value_counts()
# Out:
# Game
# Biomutant                                                                         2
# Apotheon                                                                          2
# War Thunder                                                                       2
# Battle Worlds: Kronos                                                             1
# Yahari Game Demo Ore no Seishun Love-Kome wa Machigatteiru. & Zoku: Oatome Set    1
# Battle Garegga Rev.2016                                                           1
# Kono Subarashii Sekai ni Shukufuku o! Kono Yokubukai Game ni Shinpan o!           1
# Occultic;Nine                                                                     1
# Dragon's Dogma Online: Season 3                                                   1
# Grand Theft Auto V                                                                1
# Re:Zero - Kara Hajimeru Isekai Seikatsu - Death or Kiss                           1
# ...

# %%
df['Year'].value_counts()
# Out:
# Year
# 2017.0    254
# 2016.0    222
# 2015.0    172
# 2014.0     98
# 2018.0     39
# 2013.0     20
# 2019.0     12
# 2020.0      8
# Name: count, dtype: int64

# %%
df['Year'].unique()
# Out:
# array([2014., 2015., 2018., 2017., 2016., 2013.,   nan, 2019., 2020.])

# %%
df.dtypes
# Out:
# Game              object
# Year             float64
# Genre             object
# Publisher         object
# North America    float64
# Europe           float64
# Japan            float64
# Rest of World    float64
# Global           float64
# dtype: object

# %%
df[df.duplicated()] ## no duplicate data
# Out:
# Empty DataFrame
# Columns: [Game, Year, Genre, Publisher, North America, Europe, Japan, Rest of World, Global]
# Index: []

# %%
df.count()
# Out:
# Game             1034
# Year              825
# Genre            1034
# Publisher         825
# North America    1034
# Europe           1034
# Japan            1034
# Rest of World    1034
# Global           1034
# dtype: int64

# %%
sns.distplot(df['Year'], hist=False)
plt.show()

# %%
df['Publisher'].value_counts()
# Out:
# Publisher
# Namco Bandai Games                        56
# Sony Interactive Entertainment            47
# Ubisoft                                   45
# Square Enix                               40
# Tecmo Koei                                37
# Activision                                30
# Capcom                                    30
# Warner Bros. Interactive Entertainment    27
# Sony Computer Entertainment               25
# Electronic Arts                           21
# NIS America                               21
# EA Sports                                 19
# Deep Silver                               18
# PQube                                     18
# Bethesda Softworks                        17
# 505 Games                                 16
# Sega                                      15
# THQ Nordic                                15
# Focus Home Interactive                    14
# Maximum Games                             13
# Konami Digital Entertainment              12
# ...

# %%
df['Publisher'].nunique()
# Out:
# 152

# %%
unique_publishers_count = df['Publisher'].nunique()

# %%
unique_publishers_count
# Out:
# 152

# %%
null_count = df['Publisher'].isnull().sum()
print(null_count)
# Out:
# 209

# %%
null_count = df['Year'].isnull().sum()
print(null_count)
# Out:
# 209

# %%
df[(df['Publisher'].isnull()) & (df['Year'].isnull())]
# Out:
#                                                    Game  Year  \
# S_no
# 448                             Ultra Street Fighter IV   NaN
# 467                               Dragon's Dogma Online   NaN
# 631                                    This War of Mine   NaN
# 725                                  A Boy and His Blob   NaN
# 728                                       Another World   NaN
# 729                                        Ape Escape 2   NaN
# 730                                     Bee Tap Extreme   NaN
# 734                                          Cel Damage   NaN
# 735                        Woolfe: The Red Hood Diaries   NaN
# 736                                        Dark Cloud 2   NaN
# 738                                                 Fez   NaN
# 739                                     Guardian Knight   NaN
# 740                                          Heavy Rain   NaN
# 742   King's Quest I: Quest for the Crown (VGA Version)   NaN
# ...

# %%
df[(df['Publisher'].isnull()) & (df['Year'].isnull())].shape
# Out:
# (209, 9)

# %%
df[(df['Publisher'].isnull()) & (df['Year'].isnull())]
# Out:
#                                                    Game  Year  \
# S_no
# 448                             Ultra Street Fighter IV   NaN
# 467                               Dragon's Dogma Online   NaN
# 631                                    This War of Mine   NaN
# 725                                  A Boy and His Blob   NaN
# 728                                       Another World   NaN
# 729                                        Ape Escape 2   NaN
# 730                                     Bee Tap Extreme   NaN
# 734                                          Cel Damage   NaN
# 735                        Woolfe: The Red Hood Diaries   NaN
# 736                                        Dark Cloud 2   NaN
# 738                                                 Fez   NaN
# 739                                     Guardian Knight   NaN
# 740                                          Heavy Rain   NaN
# 742   King's Quest I: Quest for the Crown (VGA Version)   NaN
# ...

# %%
# Calculate the sum for the selected columns
columns_sum = df[['North America', 'Europe', 'Japan', 'Rest of World', 'Global']].sum()
print(columns_sum)
# Out:
# North America    211.57
# Europe           257.17
# Japan             34.78
# Rest of World     92.04
# Global           595.64
# dtype: float64

# %%
sum_values = df[(df['Publisher'].isnull()) & (df['Year'].isnull())][['North America', 'Europe', 'Japan', 'Rest of World', 'Global']].sum()
print(sum_values)
# Out:
# North America    0.00
# Europe           0.10
# Japan            0.09
# Rest of World    0.01
# Global           0.22
# dtype: float64

# %% [markdown]
# ## Dropping null rows which contains year null and publisher blank sales are almost 0

# %%
print(df.isnull().sum())
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Game             825
# Year             825
# Genre            825
# Publisher        825
# North America    825
# Europe           825
# Japan            825
# Rest of World    825
# Global           825
# dtype: int64

# %%
df
# Out:
#                                                    Game    Year  \
# S_no
# 1                                    Grand Theft Auto V  2014.0
# 2                             Call of Duty: Black Ops 3  2015.0
# 3                                 Red Dead Redemption 2  2018.0
# 4                                    Call of Duty: WWII  2017.0
# 5                                               FIFA 18  2017.0
# 6                                               FIFA 17  2016.0
# 7                                       Uncharted (PS4)  2016.0
# 8                                      Spider-Man (PS4)  2018.0
# 9                        Call of Duty: Infinite Warfare  2016.0
# 10                                            Fallout 4  2015.0
# 11                                              FIFA 16  2015.0
# 12                           Star Wars Battlefront 2015  2015.0
# 13                       Call of Duty: Advanced Warfare  2014.0
# 14                                        Battlefield 1  2016.0
# ...

# %%
df[(df['Publisher'].isnull()) & (df['Year'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Game, Year, Genre, Publisher, North America, Europe, Japan, Rest of World, Global]
# Index: []
